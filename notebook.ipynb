# %%
from IPython.display import Image, display
import json

with open('colors_in_generated.json', 'r') as file:
    json_data = json.load(file)

for imageName in json_data:
    display(Image(filename='generated/'+imageName))
    print(str(json_data[imageName]) + ' ' + imageName)
# Out:
# 169 train-234.png
# 185 train-248.png
# 189 train-107.png
# 190 train-330.png
# 196 train-101.png
# 203 train-405.png
# 204 train-159.png
# 205 train-460.png
# 206 train-318.png
# 212 train-274.png
# 213 train-342.png
# 216 train-316.png
# 217 train-426.png
# 220 train-407.png
# 220 train-449.png
# 220 train-270.png
# 221 train-76.png
# 222 train-148.png
# 226 train-91.png
# 226 train-245.png
# 234 train-169.png
# 235 train-12.png
# 236 train-175.png
# 238 train-309.png
# 239 train-39.png
# 241 train-394.png
# 243 train-459.png
# 244 train-300.png
# 245 train-452.png
# 246 train-354.png
# 246 train-315.png
# 246 train-58.png
# 248 train-233.png
# 248 train-83.png
# 249 train-235.png
# 249 train-153.png
# 252 train-223.png
# 253 train-327.png
# 253 train-290.png
# 256 train-463.png
# 258 train-177.png
# 261 train-97.png
# 262 train-100.png
# 262 train-329.png
# 263 train-321.png
# 265 train-0.png
# 265 train-384.png
# 266 train-340.png
# 267 train-350.png
# 271 train-344.png
# ...
